# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavoiesb/dataset_files/blob/master/Gera%C3%A7%C3%A3o_de_texto_caractere_por_caractere.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import random
import io

# %% [markdown]
# ## Preparando os dados

# %%
caminho = keras.utils.get_file(
    "memorias_de_um_sargento_de_milicias.txt", 
    origin="https://raw.githubusercontent.com/gustavoiesb/dataset_files/master/memorias_de_um_sargento_de_milicias.txt"
)

# %%
with io.open(caminho, encoding="utf-8") as f:
    texto = f.read().lower()

# Removendo quebras de linhas
texto = texto.replace("\n", " ") 

print("Tamanho do texto (length):", len(texto))
# Out:
# Tamanho do texto (length): 341896

# %%
chars = sorted(list(set(texto)))
print("Quantidade de caracteres:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# Criando as sequências par entrada no modelo
maxlen = 40
step = 3
sentencas = []
next_chars = []
for i in range(0, len(texto) - maxlen, step):
    sentencas.append(texto[i : i + maxlen])
    next_chars.append(texto[i + maxlen])

print("Quantidade de sequências:", len(sentencas))
# Out:
# Quantidade de caracteres: 60
# Quantidade de sequências: 113952

# %%
x = np.zeros((len(sentencas), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentencas), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentencas):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# ## Criação do modelo com apenas uma camada LSTM

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

# %% [markdown]
# ### ***Por que usar amostragem para gerar texto a partir de um modelo de linguagem RNN treinado ?***
#
# Depois de treinar um modelo de linguagem, muitas vezes você gostaria de usar o modelo para gerar um novo texto. Para um modelo RNN para geração de palvras, o texto é gerado uma palavra por vez. Em cada etapa, o modelo gera uma distribuição de probabilidade sobre todo o vocabulário. Com um vocabulário de exemplo/teste, como:
#
# $$vocabulário = \begin{bmatrix}
# gato\\
# cão\\
# sapo
# \end{bmatrix}$$
#
# A saída da distribuição pelo modelo em cada etapa de geração pode ficar assim:
#
# $$previsões = \begin{bmatrix}
# 0,7\\
# 0,1\\
# 0,2
# \end{bmatrix}$$
#
# Cada entrada no vetor corresponde a uma entrada em nosso vocabulário/conjunto de palavras.
#
# Depois disso, cabe ao usuário selecionar uma palavra desta distribuição como a próxima palavra no texto gerado. Dois métodos muito diferentes para escolher uma palavra da distribuição são:
#
# **Greedy Search (pesquisa gananciosa)**: pegará a palavra com a maior probabilidade (escolherá "gato" nesse caso)
#
# **Amostragem:** amostra da distribuição, leva em consideração as probabilidades (escolherá uma palavra aleatória, mas "gato" tem a maior chance de ser escolhido)
#
# Portanto, a pesquisa retornará uma palavra(caractere) muito provável (e a mesma palavra(caractere) toda vez que for requisitado), enquanto a amostragem retornará uma palavra/caractere das palavras/caracteres mais provavéis, porém um texto mais variado. Geralmente, isso significa que a amostragem torna a geração de textos mais interessante.

# %% [markdown]
# ## Função responsável por gerar uma amostragem
#
# > Retornando um indice de acordo com a distribuição de probabilidades
#
# Explicação da necessidade de amostragem de textos em Redes Neurais Recorrentes (RNN) : https://datascience.stackexchange.com/questions/72770/why-we-sample-when-predicting-with-recurent-neural-network

# %%
def gerar_idx_amostra(preds, temperature=1.0):
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Treinamento do modelo e geração dos textos

# %%
epocas = 40
batch_size = 128

for epoca in range(epocas):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Gerando texto na época: %d" % epoca)

    indice_inicial = random.randint(0, len(texto) - maxlen - 1)
    for diversidade in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversidade:", diversidade)

        gerado = ""
        setenca = texto[indice_inicial : indice_inicial + maxlen]
        print('...Gerando com a semente (sentença): "' + setenca + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(setenca):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            proximo_indice = gerar_idx_amostra(preds, diversidade)
            proximo_caracter = indices_char[proximo_indice]
            setenca = setenca[1:] + proximo_caracter
            gerado += proximo_caracter

        print('...Geração finalizada: \n', gerado)
# Out:
# 891/891 [==============================] - 114s 126ms/step - loss: 2.3110
#
# Gerando texto na época: 0
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "nda em conta as inocentes caçoadas que a"
# ...Geração finalizada:
#   como de dia por que a para de ou dia por que se por interrado do leonardo por que se se por que o tem por que de de por que a para de ou bom o por que o padre de para de contrado de os porto de ou porto de ou risa de ontro de os porto de o como de ou nos o porto de ou disto de os porto de ontro de ou dia por que no mesmo de ou dia por que disso de ontro de o propessado de por que se por que disse
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "nda em conta as inocentes caçoadas que a"
# ...Geração finalizada:
#   se estara de uma entravam o perquer ques de onde resta de fio de capatada a sua sua o leonardo vidos em cora d. maria, que porto de como de ou disto de lisaira a desto de poré a seu por o menino de osta de por que de alguma para de nem dia como de ou leitor a por que e a contrecer a começou o seu panhara a o minga, fitando a sua no senhora em ter possa para o hasia que des inferrado, a entraria d
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "nda em conta as inocentes caçoadas que a"
# ...Geração finalizada:
#   êm de que teva de que quer muito, paório, esa a mistão porque tiam-se sobredo; vinho vandas tirpos no tédo na sodidelado, foce dos d. usquco dudo home san s. feito ante des cortesto ques o maior dissas nele des mítela que poste vora ao viveres.o: — oi, se, erte não que proze, passira tado se joi por icaça mado de corava amirmão, uma para contirou comparitiros, como mesmo por côsta-le, acabia bou
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "nda em conta as inocentes caçoadas que a"
# ...Geração finalizada:
#   deculgusfelá nxi que, ualentas era meste porquem o tos fazer ebeleram vodo, asera; ora, que se tras, meso. gão, ejenverras e ceradis,-sazeaão paralha do migo de tinham a rópos aguia aé dpo-sam na um filha: de todada. a hãoigo, vinha lagar àscatarampo o verez, pazec-lhe ses forta verdado; por levostá puielas estouru o que na hosém conção. pochanta, pousé vesta tendoasfos coré-lo. timem a gram que
# 891/891 [==============================] - 116s 130ms/step - loss: 1.6312
#
# Gerando texto na época: 1
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "que ele queria, porque internando-se na "
# ...Geração finalizada:
#  casa de d. maria de servidos de suas vezes e a comadre a comadre de suas pertas de casa de suas prinas de servidos de suas coisas de suas convessesses. — ver-se a comadre a comadre a comadre de servidos de comadre de servidos de servidos de maria de isso e e a comadre a comadre de ser primeiros de suas pestas de seus pessosos de casa de suas pertas de suas pertas de suas peras de conversas de suas
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "que ele queria, porque internando-se na "
# ...Geração finalizada:
#  casa, e com os ou dos ou deste a comadre e estar a vizinhante, como e e e deussendavam e a comadre e muito o major a vez a conversado de tranha de sentados de ser apenas a marando-se a suas partas de velho, de terrindo como e apenas porque a fer-lhe que, e procurar se disse de fertes. a comadre e em com de saber parava o major a conversada a vira de filhas, as dias de legrando a malvira de masse o
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "que ele queria, porque internando-se na "
# ...Geração finalizada:
#  sua conviria como muitos compadre ver demestes;, coisas. o neste logas, comridado gormotou o obtros. — vera das comos dia estas vidinhas foi uma gicendar do dos que — massagado dos aprincidos, se com e abradados era a que. era posto, que o major que o compadre depeito qualos elava o lugar depost; uma comadre, duvo isso não ele lavava osquircar e assis.rassos, não há uma puragasse aos moros pcciala
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "que ele queria, porque internando-se na "
# ...Geração finalizada:
#  selhe mai degro. mais que no surir d. marimente se noggeless. — isto ate!vtças enciera featose eta, casam. quegas fispançass dizerassesçda egas be seguia, decisa branssazidaderia pelasábre ela. as tuastos dequr mais paipar soíriamente com otja-la. esfanindo; logo a sémpo já vidinhos. depois o nou respegados ou leonassamismente; afor-santos. fustas de evota do queme sidares, euzias, cemédoressemcôn
# 891/891 [==============================] - 114s 127ms/step - loss: 1.5069
#
# Gerando texto na época: 2
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "ais, se delas se ocupavam, era unicament"
# ...Geração finalizada:
#  e de se persobres que entrara de este de sem desarrados de seu procurar de estava de se por um dia de procurar a comadre, porque este de seu toma-largura de se disporos que estava de como por isso porque este de a comadre de seu procurar de casa de a procurar de que este de o pelo menos de seu procurar de tempo de se promesto de que este de este de seu procurar de companhia de se por interito de p
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "ais, se delas se ocupavam, era unicament"
# ...Geração finalizada:
#  e de ocasião de se disponto de deus imedia de um de estava à seu instancia de que este de tratar que dizer a a seu a promesta prometia com este por isso lhe dirimante se discíplitos que era be estava que estava este não temenos este de levando com o leitor de acabeçado de que este por que lhe estava se dispois desesperava a posto, pelo compadre, porque ele por um entrar o que estava foi também em
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "ais, se delas se ocupavam, era unicament"
# ...Geração finalizada:
#  o que inceito, e prevestidamente neites, e o que se dispensava... o seu seu vordadeito; devontosteisareis; e com a comadre e a. major o queria do o pohco nastavam na sem quero, muito de lajciues, que queria de tomamente um feligado. entrava no pego pais depondido de que se dize; no mestre sus à arfelis da cquis pesbos, braçam nesse tempo do amão, tomem entrutamolhas com o penito num coml!.., tomav
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "ais, se delas se ocupavam, era unicament"
# ...Geração finalizada:
#  o todos oram ao ma! aréi, dixoca prompre obricório, e que pusovambício, que fedis, peto nanada turestra. o almairão largitas, embrolo, obatilho por de foi vora, tinha coisa eram dinigiram na berra-lhe soubemo enteceder-se es ertular meis do besitítioiõo de coisava trantalho em quebo comfica, que nem seu que paditicação , que fo sutago se diriganda vatispeno veci não o permão, be u, frusufescárto,
# 891/891 [==============================] - 117s 131ms/step - loss: 1.4371
#
# Gerando texto na época: 3
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "s de teu parto.” são palavras de jesus c"
# ...Geração finalizada:
#  ompanhoramente de seu padrinho para o primeiro de seu padrinho para a parte de sua comadre primeiro de concerto que o leonardo porque em que o leonardo por esse destas coisas de mais de disso, e a mais a comadre a comadre de dissemos de a vizinha de companhia de sua comadre de dissemos de mais a vir a dia de mais de dissemos de sua comadre para a comadre para a comadre por isso porque o padrinho p
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "s de teu parto.” são palavras de jesus c"
# ...Geração finalizada:
#  ontrados como em parte de coisa a dia de imperizer a mais randa em parte com a cadia com o mais intermo de uma pagoa de agrado de os partes, e pessos de tal não morida a comadre, de um par do que o leonardo quer meia de casa da sua leonar de os olhos de a , mesma em que o que estava de feito de tramar de cada de mosto de casa de que o leonardo não haviam que era uma capaz como tragar a vir a sua r
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "s de teu parto.” são palavras de jesus c"
# ...Geração finalizada:
#  onfigas desatdos, em os que o pohio. dartada contra passaa é, dissem, lá a idriamente dos comos no ofílio, não presa digra dalgante. o leonardo não era a maitr bemfera esta, valras que algumas por umas por dias por alguns argado... apospavam ao risado. naquela reindijo, e não para em feito. coisas dariarias não capaz começamenter por luisinha parendo que haquam a fora acasa de luisinha, contraria
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "s de teu parto.” são palavras de jesus c"
# ...Geração finalizada:
#  antes: filho aq:inoto leonardo. em feliz de acasidado; mostranham-nia, aferil marto xervovamá, emquendosoecebram. tonanábo quera, casa malérin d. vanha: há-la de que quero ósuoo, crida... sobrinido... um aérou e ainda não ao parto que os umaval. o compa! dedre do viviorira, vorganeios o neisso muigo alguns quando-pedim tornazame dos tormel, respois, os dois pritisos de luísinha aligio. e qualquer.
# 891/891 [==============================] - 114s 128ms/step - loss: 1.3931
#
# Gerando texto na época: 4
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "bém não era das que se receava com qualq"
# ...Geração finalizada:
#  uer de alguma de companhecia a comadre de contra o menino de ser alguma coisa de tudo de fazer de d. maria de companhecha a comadre de alguma coisa de ser alguma coisa de concidia de companhera de ser alguma de companhecer a comadre por isso era a comadre com a comadre de casa de d. maria de ser alguma descrimento de ser outro de companhecha de ser alguma de ser alguma coisa com o leonardo então n
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "bém não era das que se receava com qualq"
# ...Geração finalizada:
#  uer perderdas de alguma coisa ali com o que não com a realizando o praço de preticante entrara o compadre de ver-se por contra a procusado o compadre foi tomando alegou de d. maria de lugar leonardo com a fazer se deixanto a vinha desse não estava a todas as novas; armente os olhos suspontos, a que o desmentia um pretento. os osgos, disse o bem pendemente ele que muito tempo de d. maria de falada
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "bém não era das que se receava com qualq"
# ...Geração finalizada:
#  uer internofpecido nessa vez d de um cando do seguinomento o prencolídera caritum de luisinha: dizia calcava; e venha-negante muito tempse a ladade explicançou essa sua: havia das ínfelizidades; e tendo as viu por muito mais dele, e prentida com pôde cixavelesse a minacuraferia, um modo antos passa das coisas. — encimevam que tudo ques ter trazias e ainda não seriam boc, como estroteja, e salturuu
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "bém não era das que se receava com qualq"
# ...Geração finalizada:
#  ra-lo, é hoje acusava entremeria, tinha-lhe os meria. valha-o gão ego qune, e se ser bemcava por sua ferdec-mem o oforetar em tudo. luisinha acreceria-se quis mulher nenduésse grinco emendariatembriros, e então esta osão e tem masafiofe eleão seu tom a festrão se a outrim... ele que todos aflações semitou-cero posco bem puderou a convesso, e colorro cheiam melhor verdadre pois quem estava dia ou m
# 891/891 [==============================] - 114s 128ms/step - loss: 1.3600
#
# Gerando texto na época: 5
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "perara chegar a todos os fins, a que con"
# ...Geração finalizada:
#  tentava de desarredade de primeiro pareceu a comadre de casa de seu pouco de seu padrinho que tentada e para a comadre de contriar a comadre, que de mais de seu padrinho para o leonardo para seu padrinho de seu parte de mais alguns arranjeiros pera o leonardo para o leonardo tomaram de seu padrinho de uma desses desarrar a comadre de desarredo de uma desse de desarredo de seu padrinho de seu padri
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "perara chegar a todos os fins, a que con"
# ...Geração finalizada:
#  seguido em sua parte de contada em seu pequeno contratanto as dias de destina de menina tomara contra a via-se de deste de todos que a conversa, tinha mais de que fora a comadre que tinha ferradade na cara de antiga foi ternar arranjeiro o leonardo de mais como foi para mais de procurera de mais tempo ser desagirara este desarretado a seu primeiro para seu alguma vez que tentou o leonardo talvez q
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "perara chegar a todos os fins, a que con"
# ...Geração finalizada:
#  seguir embreros. porém essava fortuna. para leonardo? outras devesterias paratas, e semelhante, desobriafiam no saltouamente um novo tarde de disbea em luas esperanças. vadisera da cigana de bolas propessiala, parecenda a busta... a vida fosse. —soénra para-se ocusotou umas de resindado, e lhestava pou tomar natulição; luisinha, passava um uras também, humersme de uma casa com o rapaz a d. maria p
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "perara chegar a todos os fins, a que con"
# ...Geração finalizada:
#  venha eu aptplar sem lão vergição, a solera porciubamos cené vestadicálito desdepatão. uma muito canto o leonardo passava um leuto... nengo ula. é elas cosagars. elas pejavam quem prepeito: quando se veelestem outra. — jíàserhada. ainda desfatado a cigana nos cumpanvas, filitraniara de não telinha molestgelanjo, nem por amanaclosa, voladefeito em teátu, aparecer lá da rua, a si, é quem se acadava
# 891/891 [==============================] - 116s 130ms/step - loss: 1.3333
#
# Gerando texto na época: 6
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "xagerado. — fogo, replicou este; se ali "
# ...Geração finalizada:
#  de d. maria de que ele por isso em desta vez de casa de mantilhas de casa de uma deles e de uma desta conversa da mantilha de casa de repente de que o compadre de seu pequeno com a comadre, e de algumas propris de sua casa de uma respeita da cabeça do major a comadre, e a cabeça do major por casa de seu pequeno de uma mantilha da cabeça do major a comadre, e então a comadre, e disse a comadre, e d
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "xagerado. — fogo, replicou este; se ali "
# ...Geração finalizada:
#  da que a caminara dia de mantilha em casa de uma dar em corrado a comadre, e por trascos repertou a ente de que muito de dirigira de manda de uma desta respatia do vidigal dos ou mantilho soldar a força de casa de d. maria da momenta de andação com a cabeça das velhas de riram, e tendo o primeiro desapirar a comadre, e não foi não queria consentar mais dia de a sua vidinha do leonardo vendo-se sem
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "xagerado. — fogo, replicou este; se ali "
# ...Geração finalizada:
#  e emprentou viste dos, apenas para d. maria logoa então a  que tudo olhara desde a respeito de conversa! queros a festa dança com rapazia a comadre de nágre maria teve com lugar só o presegretar e mode de criadado, e modinha reganditento isto, edto. ção passava que não prota. e eno mantãamente do leg; decipimar redosso dantenção a enfulta do cima do menino cripass rivavas, tinha a esperar tralar q
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "xagerado. — fogo, replicou este; se ali "
# ...Geração finalizada:
#  porivas deixas dos padrem corou; concispência go. triuam mas não modivo ao minores de voz pejugrava com eximte chugando enguar! o caso esta comadre, e não dos onfim outriu que fizem  horrinadopento. boa d iniriu-se com apelho de havigartado? o ema sanpa, como não haventouê-se; na causa quantanda, q e não saio-chamar por coréde ná certavia a mantilha, que este uma rocusadica. é há de senhora que as
# 891/891 [==============================] - 115s 129ms/step - loss: 1.3119
#
# Gerando texto na época: 7
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "as preocupações eram o objeto de estudo "
# ...Geração finalizada:
#  que estiva de algum continio que estava de que ele porém porém o padrinho que ele porém se podia com ele e com a comadre a comadre não se poder que a comadre estava o major para de seu padrinho quando mais de algum contido em compadre a comadre de que estava em parte de seu pequeno... e se achava a comadre para concado de seu padrinho que ele porém não se poder que estiva de seu padrinho quando po
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "as preocupações eram o objeto de estudo "
# ...Geração finalizada:
#  o que isto quer de rua com a comadre develo que aparecia maria da concar em que a cabeça de uma concoira de sua compadre que ele quares, e com o leonardo morrera a noite a comadre passou a comadre parecimino avandir-se com o leitor de conceço de padrer... isto querem mais mundo a sua companhia o compadre e vinha a comadre poder em pouco o major pesso era um sarilho, e era contra em que não saberia
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "as preocupações eram o objeto de estudo "
# ...Geração finalizada:
#  a moda que era aqueles malvraquela vizinha, que se pisa-sidamente tempo seu afilhar, despeuco, e só meirer que não pega tinha tices e desde todos esaperfentires, ingamos enquantos murrentes que compaisanhamente d. maria verdade aé poder em desescorado, dizer mais das entraram as seus, e , um bem desotado lhe também parece saltado o dizia, até à crátar juntar em sobre um bom nosso mafei viu-se entr
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "as preocupações eram o objeto de estudo "
# ...Geração finalizada:
#  em quastereaza; foi resposte em àste que quando por usu nocho meio de grande vu dibriclar-se basichortão que vibga-se viu-se dadola remotirava-lhe homem, musmo, que desor... porém seo mem decuboto pjuco cárija... estava-na com elei... mas de olhar no susturio, com o tamose o msse. o mesmo tempo, ao seu conimem os tasosentos e podiam nem o soldido de efeito o meeir semembonçamava com ele, sabem à p
# 891/891 [==============================] - 116s 131ms/step - loss: 1.2936
#
# Gerando texto na época: 8
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "em; veio-lhe outra vez à lembrança o pon"
# ...Geração finalizada:
#  to que se por onde todos os olhos de padreiras de seu padreira de passar. a comadre perdera de seu padrinho de casa de poder de mais dia que estava a comadre tendo-se a comadre de casa de seu padreiro de seu padrinho por algum sento a comadre de mais indigar em casa de ser aquela pareceu a comadre por esta conclusida e entre a cadeira em casa de seu padreira de mais para de mais diante de mais des
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "em; veio-lhe outra vez à lembrança o pon"
# ...Geração finalizada:
#  to que se procurava com começar a mal para para o vidigal na casa de mais pouco por todo o nosso major para o compadre a sua contra em que o leonardo como tormando-se em lugar entre a casa de levar a mais para a moda da intença a que ia que ele por antes dar estar de toma-largura amardinha a amolada e perdear a cabeça de seu padrinho, e o procura que ele que se principalavam que o estivera estado
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "em; veio-lhe outra vez à lembrança o pon"
# ...Geração finalizada:
#  to, as batimas depois com se por custoum... disse dirigindo-se de sua gerar, quele todos leonregados nos verdareciantes, disso; e com muito tinha feito o que ela esta, cressando-se. isto repetina havia atia meter coiu-se. o pessotou-lhe as desforridos: muidos chorme feito na caretra, deu rara-se para quis varteles ninca mhemostes. as íntumos perdoares, que pareces; então feitas aceu entretanto vie
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "em; veio-lhe outra vez à lembrança o pon"
# ...Geração finalizada:
#  ça tifura, ceria começa o sefinhou por amagente-veia um malicido d. maria fizera o f-sa cbsice, largazado-se para. enconveras, e já nadia em coiço, há de mais pachado apresplucado; éus começam trazia chamar-se-de que também não, quis fazel no que nadigó tamente. pessoram, chegado em havia-se, de dd; anão lugar-ma opassara queeneiram sabiiva! — dara bom nos interrompir foz c ardua; tímandado. lu, s
# 891/891 [==============================] - 117s 131ms/step - loss: 1.2782
#
# Gerando texto na época: 9
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "sa senhora; foi depois desatar a fita da"
# ...Geração finalizada:
#   comadre, e a comadre, e ser apesar de cada sera de cara de seu pergunto de ser novo de ser tempo de seu parte de ser deste tranar de ser algum deste alguma coisa que ele apenas o compadre de seu pergunto de ser disponto de ser dia que a comadre se por algum continuo por algum dizia um conhecido de alguma coisa por algum dizer, e a comadre, e por algum deste de desapresar a comadre entre a comadre
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "sa senhora; foi depois desatar a fita da"
# ...Geração finalizada:
#   sua convidade deste consigo de toma-largura esquica da vindão não se punha-o por aí e caba, e deu ao altormedo que ela porém desse porém semelhante esperança no mestre-devia de cada indtação da comadre; porém a comadre a primeiro fazer vidinha do leonardo, por não entre a vergade o leonardo-pataca e que por ali mesto se era uma desade de ser deixar naquele tempo menina presentando-se a procissão,
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "sa senhora; foi depois desatar a fita da"
# ...Geração finalizada:
#   paridade enchiço, croir, cu, parar exsciai elo, disse o saivo ela estavela que a ocasiõe o mestre-se que não viu deu atrivilidade. estou por havia porém por aí a vozenada então os primos, dançavam isto; o velho de presoriva-lhe para desta vez, e presar muito cravizava. a intertera, não se os segrados que entraria negócio também lhe nos desoridos, não o noio desapirar o cação seis nosso canária; e
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "sa senhora; foi depois desatar a fita da"
# ...Geração finalizada:
#   verdade; de levar-se àquiz meito a patecar parte que era aria largu-se unicançar com depdi em nissoré al capitão forresse, junto, ia vinturar vidinha, ssiu... reanção a um dos curimantes. ele não se valdantouve a seu quardo, porque nus tirhas ferro! uma dtei havia um telho muito tomage-se, a ao leonardo-pataca que tinha continuadí, mas apunha-se uma pinha respeito há de num serprade. aentaria par
# 891/891 [==============================] - 118s 132ms/step - loss: 1.2665
#
# Gerando texto na época: 10
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): " de povo, especialmente de mulheres de m"
# ...Geração finalizada:
#  enos do padre; o seu parto de sua própria do padre; o que ele a porta de sua casa de maneira de seus passos do seu parto de seus partidos de suas partencias da banber partida, e para disto do major a comadre de sua casa de uma maria do padre; o padre; a comadre, e a comadre, e por isso a comadre, sem deixara da casa da maria do passo de sua casa de ser leitor de contasse de sua casa de seus partid
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): " de povo, especialmente de mulheres de m"
# ...Geração finalizada:
#  uito começo de seguindo de medo, disse à sua medida do parte para pela leonardo por um dos dentes de seus bonitos, foi de estadeira e que se achava ao pontrnido. a porta. desta vez que o leonardo não sabem de seus fazer assim porém a sua parta de suas comadres cercadas por tempo de tudo para a comadre do seu feito do todos os homentos do seu pai.... — sera, disse a parte de todos a fazer maria de
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): " de povo, especialmente de mulheres de m"
# ...Geração finalizada:
#  aneira quando o vento guro que tinham dentro para aflaçosó que não para levado com departo por verdadeira com entrado, e ombro vantavam entretanto quares que a tinha saltado um seguindo; pinga quees em discinter tamento engantes ecimíciomavam ao leitor arraàs e começados do vadiss. e ainda a ficar o que se aos bonibos, saltava se entara quando deixarais da verdade em contentido a pílo da sua estar
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): " de povo, especialmente de mulheres de m"
# ...Geração finalizada:
#  uito capaz-se de borôs contou daquela hordanhar, comadou de minha írnalmenta  idéia um que por casa, contravejeu-lhar-se o zenos uma lada. e a penula por cuidada para chegar a puza de pouco quem..... essa conciloa, senhação desta comadre, inbarrizando os leitores det-cadas basorampestas; tomando ensegueram para tal pvocantada o àsso tão pregando-se deixar de casa para terdamento, nem semhião, mest
# 891/891 [==============================] - 118s 133ms/step - loss: 1.2557
#
# Gerando texto na época: 11
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "ratou dela; as outras não, coitadas... —"
# ...Geração finalizada:
#   vais estar a comadre para como em como estava a seu pouco por alguns cantos e a comadre de casachar a sua comadre para como era a santa da mais desaparado a comadre de seu pouco por onde por isso quem se achavam todos os meios de como estava a comadre de seu padrinho do seu companhão de seu partido do compadre por nada de contra de seu partido do capitão de seu partido do compadre a comadre por s
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "ratou dela; as outras não, coitadas... —"
# ...Geração finalizada:
#   cabrava o compadre a que se achavam a comadre também a cabeça de seu pouco por castura, e a mulher o almouro de menino, a comadre de ser em sua antiga rapaz encapito de seu primoito velho tinha lhe decimentou de santado em um dia de seu proceso de muito tempo de filha da cabeça com o leonardo por seu prociso de dar-lhe a comadre de modo chico que entrara a seu nome de conta, sala o mestre-de de a
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "ratou dela; as outras não, coitadas... —"
# ...Geração finalizada:
#   era motivo obver a causa empleço fazer, como de pouca de suas olharinhas da vizinha, deitas o negócio de milmiviu de vedões. — e pois a sua casa. coiz, deste uma comida expalinhou cheivo celo-te e uma proinfõe tudo que assim, proposta alguna sargos de vir em razão de mátitira que se ter voltedão. luisinha em um compaitendo foi com grarndo de costas, e negócio, mas o sea coração estroátar ia linga
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "ratou dela; as outras não, coitadas... —"
# ...Geração finalizada:
#   nem, as rrataídes que te dá algocado dele, sabia seiándomete, partidoas, não saiu é l. guarna, ao desaciada de um apelo lícàplou: ficava casa vida compoió viam agora à crgação em seu entrendo. dava-melhe uma aveemão, pois punquido, chesto como o que foio para memo tentado com murmez comprefeito. os esperars e queôolhavamse lado do leonardo: a sentomanta ver bragaturar era sente da maus seus seus
# 891/891 [==============================] - 115s 129ms/step - loss: 1.2443
#
# Gerando texto na época: 12
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "sto como quem queria dizer: — está bom, "
# ...Geração finalizada:
#  e entretanto de mantilha, e para com a comadre, e o caminho de casa de seu porta de seu parte de casa de seu porta de seu parte de seu parte de casa de seu parto de seu parte de desarrindo a comadre, e com a casa de um dos dois um dos seus entre de seu parte de seu parte de casa de seu parto de seu porta de fazer de seu parte de seu parte de começado a casa de casa de bom do leonardo, e entrara de
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "sto como quem queria dizer: — está bom, "
# ...Geração finalizada:
#  e ele valer de ser aparecer com a sua boca casa da sobrinha, e depois de desurredo. e o caminho, como ele fora desapinha o capitjo em que maria de bom capitão de seu porta para um nome de padre; a seu rival que tendo o padre; entreva-se ele a que ela e dentidade naquele dia; e com a menina, de casa de seu pontumpela de fulhar de uma casa de seu pisso da cabeça de tranto de seu partedia de seu part
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "sto como quem queria dizer: — está bom, "
# ...Geração finalizada:
#  como se metice, tomara esperto de munda o trabante questive ativente anter, e que estavam davam alguns as coroções as rigoés os converses de que quitoe no dole, violente, minha primos, o vidigal que tr.tmalho e soltes não : ela, como se dizbmeno, porém que tendo pinha há de um coração tempos tem, oa capaz, o zanto de desespera o compadrificido de perderquinar na ca pesso a seu ribal e ganho amoras
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "sto como quem queria dizer: — está bom, "
# ...Geração finalizada:
#  com um pouco. o leonardo o vamos que ajuca. — porque entrapre; também nenhum vidigal-nei, foea lá o compadre, porém elto lençoár coisa. no padrinho-moresse eme-que tendo este em cincipalenite não foi é um padre. enver. do que unia visé a quises, armigo de atório; vendo-se parece há maur poá ocer anda à comadre: — arícê. motou de uma armar nós fortu se juvgar sua enárecia com a bugora. ela, de arra
# 891/891 [==============================] - 117s 131ms/step - loss: 1.2372
#
# Gerando texto na época: 13
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "sam estas cenas instituições muito curio"
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...Geração finalizada:
#  sidade. as velhas de seu padrinho de trabalhos a comadre de tal era a comadre de alguém que tinha de contentada e contra ele, e apenas algumas soldadas por cabeça de contente de uma vida e de destante de alturas para o compadre de cada um dos passos de seu partido do compadre com o leonardo de escontada a comadre de contentar a comadre por isso desse de todas as de parecer. a comadre, disse a coma
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "sam estas cenas instituições muito curio"
# ...Geração finalizada:
#  sidade de cadeiras e pertoras, o camo de compadre achou-se a ppuga por causa do leonardo-pataca, e preondeu de visto de precirou-se em que disse um companhio de ordentas, e entre a cigana, e a comadre de alturas para contrado e cuja comadre foi por ele e desafirar dos olhos de uma maria da causa de ser contra e cabelos de medo, e estava ele e mangava que se achava o que se achava de todo algum est
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "sam estas cenas instituições muito curio"
# ...Geração finalizada:
#  sido: ela e padrinha perdencio e a cabeça se lhes ripariga, disse apenas padre, e arrendo já encantrou que não tiveragalhia-pjáriga, o compadre que vielara dele dizia às tas partiginde que lbe de casação uma compoifivida, e uma cortura empredir e fingo quando a revondedo pelo major: ela conciliado para cinsu, porque não não não se sabem um vedica quidimos de cofer e ele, e deeva afontivacípos e le
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "sam estas cenas instituições muito curio"
# ...Geração finalizada:
#  s avidade, tera, á com ver tro convidoes quas não queriam andar e viage-seco; ele abriu uma sentido com efeiam p... — ele lhe menquira, e conservançou-lhe do seu batil com isso e divelamente chiquir-se você, sravas senhoras sai., e o leonardo portanto à rebalição de desorrindo um si-lho as, aí quepor, repontáva disso: o maldisita; reitou-se no uma caritanido comproce alguassa sobre açonde a idade
# 891/891 [==============================] - 113s 127ms/step - loss: 1.2286
#
# Gerando texto na época: 14
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "o prazer do fado e das cantigas começou "
# ...Geração finalizada:
#  a porta de sua mantilha, e por este por que ele por isso que se achavam que estava se por este tomava a porta da casa de sua companhia de sua parte de passar a comadre de tudo a comadre de seu partido. e a comadre de seu partido em costumento de seu partido de concilhana de ser amora da morte de sua companhia de seu partido de ser amigo de sua companhia de seu padrinho perdera de tranquilha de sua
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "o prazer do fado e das cantigas começou "
# ...Geração finalizada:
#  que levava de que a comadre era a comadre de de novo de sentada um pouco a comadre com a comadre perguntou e tomava a sua verdade, e sobre que não saiu mais luisinha e abrirado mais o menos a companhia, e com a comadre é muito contrariado os padrinhos para curacência. vidinha a comadre por ele perguntou para coisa casa para terria de ser afilhado que fosse com ele, que se achavam por ele a comadre
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "o prazer do fado e das cantigas começou "
# ...Geração finalizada:
#  e deentendo. com quem era passava, jouço; enver modinho. — interralueia: — mas por fir o que entrara de bantos tremando às veltas, e o nosso outro clojo passada. navia a digementa, era arranjado, e perte-denfeirimas esparavam-se impina! dizia para concpolhado grande sanga da encasada, que dá em param; não lhe selvião, e ficaram da casa, disse, a procurar logo a que dá se entiveiro: — era essa esco
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "o prazer do fado e das cantigas começou "
# ...Geração finalizada:
#  sandar isto era de vidinhanifizaçação, ap. nada a coisa re a um emboja horajiês com o leonardo, consevou; está que uma corpor da circunclimadrag-se. se fazio, badilha esse seus. ver surdens, deu-seq.ecis, em que tinha sitrêncio remitavidava-se é sigrec-saturo, satiumose pudente esta velha... sigcangecia a, solheceu sempre sogridou a adrisar, achoiam nunca ficaria tranqurenças de ele, e o que havia
# 891/891 [==============================] - 115s 129ms/step - loss: 1.2215
#
# Gerando texto na época: 15
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "rém ainda observar que o amigo do leonar"
# ...Geração finalizada:
#  do para tanta comadre de sangria de sua comadre de sempre a comadre para a comadre de que se paravam o compadre de ser a mais para de sua casa do leonardo dizia com a comadre de recolhente de sua comadre por outros dias de desapresada de sua comadre, e de mais alguma coisa de sua comadre de santa de mais de receber a comadre de contrariado, e como se precessava a comadre de seu parte de ser alguma
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "rém ainda observar que o amigo do leonar"
# ...Geração finalizada:
#  do foi quem se decessava a ser aquele despeitou-se a praciação de ver que desse contimaram-se a mais mais aquele contrarinho a sorrina de procurar-se ao entro. de ser adiante de santa de respeito destas ante, porém entre deste perdendo por este contrariado. — foi o compadre começaram-se em que ele por alguma cricava que tinha tempo de alguém quando era mais respeito de procusado. — semhá. o tempo
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "rém ainda observar que o amigo do leonar"
# ...Geração finalizada:
#  do chicando-se à tremena que lhe cantente de rapar-lhe sanácia com salgava-o. — epois aos dialras; sucedou mau-regalinha: foi uma viaida. o compadre, a uma reza. d. maria quando o dia: nstom de qualmor em todo para o moçova. mas idoiúme um como reculou reperto para mais que pravam descontecer de cerem... mavaà era sem r decordia tinha oferecera mais praçalhariam o leonardo de a imidada, e depois c
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "rém ainda observar que o amigo do leonar"
# ...Geração finalizada:
#  do-cecchê pogada,u. esta madrinha, cheia: se em último faço. mas o princo quem tenha o compadre dole porque sobre ter quando o a-! pedo. —voê-ceso era probesta ainda na cabeça... e inte, começou uma dasfercamas qualé. d. modo. desses vidigal-do, declazou-se ele, contraqueles dava; aquela miêmia começar ondelo todos, o pesso, conhecer... — o pantade; acomestia; porém que se do seubre namento todos,
# 891/891 [==============================] - 117s 131ms/step - loss: 1.2147
#
# Gerando texto na época: 16
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "o, o que se acabava de passar não era se"
# ...Geração finalizada:
#   por ou teotônio do major vidade de todos as mais de para a comadre, e a comadre de algumas para a comadre; e a comadre de mais de seu pobre rapaz de seu pequeno de mais de seu pobre rapaz de seu pinha, e a comadre de mais de mil com a sua pronua da casa do major desde que se achavam a vizinhança de seus para de mais semelhante de seu procurar de transtento de seu procurar de todos as mais semelha
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "o, o que se acabava de passar não era se"
# ...Geração finalizada:
#   por isso o pobre homem todo o compadre por que a comadre a primeira de conversas por sua vida; e os leitores provez deste proveu; todos as malinhas de um pouco e fora de bairema com a casa do leonardo, que estava, alguém feito de cada eração e uma primeira do seu novo de d. maria-já isso o leonardo por as coisas ao major vozo de mantilha, disse o seu precios de compadreia por dente; era leonardo
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "o, o que se acabava de passar não era se"
# ...Geração finalizada:
#   como reculava tixo pratável, e abrira-se de d. maria por meu terma em que escupavam os seus que devotou a senhado como o lhe depois modira, rompeto de houpa-se, arrarrou-se poucolo aquilo que dêsse abanado, e desforam a ônicajeja o negócio instavam em pulado contidamento da conheia impachou. d. maria, dizes fazer: — êà por seu ava ocupa daquelas dras por camita, era o mais empretreto do mundo, po
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "o, o que se acabava de passar não era se"
# ...Geração finalizada:
#  u repédo nuncas. tinham maria-regatamento o que haqui se valer selheu-lhe uma leonatra, pois outros; terém que por mais dar-lhe elxa por se arranavamá, era seus vinham a lido esperam, não, sindo mome conhecim, questento o major vmampa, -úli sarjo tortejos bem setivamente-lhe o resol. isso instguia um pouco em cá, quase amua era nigramense, todo tudo quens, ? quem uma vez, vordaram ao compadre, se
# 891/891 [==============================] - 115s 129ms/step - loss: 1.2107
#
# Gerando texto na época: 17
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): " o afilhado, e começou também a contar a"
# ...Geração finalizada:
#   comadre para casa de uma das madrinhas para coisa alguma coisa alguma coisa em contente de sua companhia de compas de senhor; de cada em comadre de cada em comadre, e que estava com o leonardo para entender a comadre de contentado de sua casa do major acompanham no que tendo que as mais as de ser amigo de sentir para a comadre de contentado a comadre de certas coisas para a comadre de carreiras d
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): " o afilhado, e começou também a contar a"
# ...Geração finalizada:
#   comadre continuada; estava ele as disciplina. fora entretar de perdado em contando de repente em um dos pernos de uma raparta fazer a família em tempo de havia em dizer, para de simple de modo o leonardo não se era contra assim com a senas pernas de fazer escrava entende a casa da sua parte, e com isso o major viam a primeira em casa de com esta a comadre, a mais terta de carre com a cabeça de su
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): " o afilhado, e começou também a contar a"
# ...Geração finalizada:
#   contar vinturas, que acertos sem dúvido, e hivem. — porque o afilhado razão, e eto que se achava amorto em portamento desprevava-lhe a belisada grande sentida pelo mouto lhe depoos nem fora o deixou de sua escroça assimência a ao mono larios de achosado a tambés de estas . nesse gintra, e do menor introdo. porque no menino de contaria com a padre retando o espir. coisa; de vinjuceira. não seria s
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): " o afilhado, e começou também a contar a"
# ...Geração finalizada:
#   coisa astanca dos íbbeliceras vezs, em tinhametar traníspo. leonardo proi?oso: restavam disopranvel, porém no coma doca o leis pregagremos, ingdoto tom a vizinhança javaro como uma onde sançap. mas tirava algum imendida grido. bem modinha tundo gondo o penafa de menino visimêm feito, como d. maus quis ser; , anos para nadaiência, cercentiram-lhe quem tenho exatem os mulhos, senão ele pecumindar p
# 891/891 [==============================] - 116s 131ms/step - loss: 1.2073
#
# Gerando texto na época: 18
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "o. toda esta cena que acabamos de descre"
# ...Geração finalizada:
#  dados, com o leonardo tinha servido a conta de contas de sua cara da cadeirinha de seus passados do que ele estava por que se achava mais alguma coisa com o leonardo por casa de uma voz dos padrentes; no mestre de vidinha, que o para extirou-se no muito antes, e para volte de casaca de uma coisa a comadre de todos os dois algumas achou-se a procurar a comadre, e para valente; e o seu para de casac
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "o. toda esta cena que acabamos de descre"
# ...Geração finalizada:
#  dados, e de era muito antigos e mostros, e que o leonardo estava alguma casa do major, incançar e até na cara, e por casa, para casas, de cada um bolelade de algum tempo entre os perdendos para que o por infelizido, que se interio, porque estava a sua sua entender o algués, a sua dentria, porque entareceu a comadre há de uma sua sigênia finalmente as ruas da casa do leonardo, porque o para a sua v
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "o. toda esta cena que acabamos de descre"
# ...Geração finalizada:
#  rrravaga; ele arrencararam de alguma posiviu uma rua da noite volite preta, a e exchimento começou a perdendo por casa, saísam a reza e para, chincirminhada, mostrou até que é pormo se extem uma comado por d. maria, casaca, pois porcento talvez um dia conta delego e soubera pelo monr. coir; que nada-se por ciéma respois vaziatvos naque de pequena, que costuma; odando-se por que a primítia desado,
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "o. toda esta cena que acabamos de descre"
# ...Geração finalizada:
#  dados, ronecir a certeles. e e daquele apelora que era, interrodão r sinalxeinar-se um la. vidadeiroua de ouvivemtria, contava os ínos. e o vana, estava enjetado em rapariga. leonardo vedo do guounum maira das mais aquele com inforrou-o a pregada algum tema por sua órto jásem agora pretess?... e o lhe disse a que estiva acabava-lhe um ? sujor ver, passava de graças nadaram esconhorndo pelo e velha
# 891/891 [==============================] - 115s 129ms/step - loss: 1.2002
#
# Gerando texto na época: 19
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): " de hoje. entretanto digamos sempre o qu"
# ...Geração finalizada:
#  e se passavam o padrinho a contra por com a comadre de ser alguns as desenvoltes, e por aquizo que ele se passavam por conseguir a contar em que ele se acabava de d. maria em conta. nem se poder que a comadre de continuar a primeira começara de mil tempo de ser alguns as de seu ponto. — solumante as mais semeções da concorquecada de uma cada contra do menino da conciliada do mais ano de uma concin
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): " de hoje. entretanto digamos sempre o qu"
# ...Geração finalizada:
#  e temos presto de posto de uma porta e casa da casa, e tomava a conciliada do companheiro de ser pedra de tivesse de tal e a sua amor da casa, acompanhadamente sabendo a seu passo do seu ou tomava a seu pouco tem este por ele acompanhada todos as mantilhas como ele se esteve a contar de uma minha prima, como lhe tinham continuos por o companheiro de morte, menino, acompanhados por esta vez um temp
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): " de hoje. entretanto digamos sempre o qu"
# ...Geração finalizada:
#  e se pode mantou: boa deste não se gostos, segundo, e um vidigal., e defroúçaria da mão. endia, colocar. também em que não aninasfel... história que ele supentinho-se-lo, não sá tirco contempo para dado o oeto o mais obaleto como tomava todo o pobre par todos uns ora, como todos os curinhos que uma mais e . duíssibio deste almes gostos per onde vê-la a, sem lença por uma cadigalidade não era taven
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): " de hoje. entretanto digamos sempre o qu"
# ...Geração finalizada:
#  al costume e poncio chegado que me por onda?; fosse o que vinha que sabiam durante, solobido o reci..... drava o lengos noites dia, convinando inteiro, o menino melhor amigo semem!... outrada, digo-a dos graços da casa do pogo enconde com o espaddo subir o avaquela er. quem devia rigo, fois foiá.iao com sua conpesferndia ao santo reugado, entretamlência para issea. naquela arrous, até havia sermão
# 891/891 [==============================] - 116s 130ms/step - loss: 1.1959
#
# Gerando texto na época: 20
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "e já sabia as ruas, e não precisava mais"
# ...Geração finalizada:
#   de tudo que a comadre de alguma coisa a comadre de barreiras de descuir a roda... a comadre havia com o leonardo por um padrinho em conta de alguma coisa a respeito da comadre por um padrinho que a seu prima, e de para a comadre, e a comadre de uma casa de amor de sua comadre por uma vez em proso a comadre, e a comadre com a comadre, e a comadre era a comadre por um dia de uma das coisas para a c
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "e já sabia as ruas, e não precisava mais"
# ...Geração finalizada:
#   ou mestre que estava a comadre, como era a comadre, porém morrevam de mulheres, a comadre, e de sua velha. por um disso a menino a todas as arranjas, com repledar a prosaria de sua prosufa, ou a avancer. do major a respeito do chico-jucou por ter feito, e de casa que se passava para a comadre, que ele acharam como se estava com o menino disto, e estava a comadre, que aquela para para excessada de
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "e já sabia as ruas, e não precisava mais"
# ...Geração finalizada:
#  , respondeu. foi estada, excessadam trouxe ; onde por. a comadre irmando, ainda mundo de meura... verdade-r coisa em algum bem verdades de arraxava sempre disso, aperar-se empregado para aquela arranjação um vamor passagado qualquer. a falar de rdes: o tempo visto do leonardo por mui espregado; passavam o lizer a deletar de presos e andadá, quando adrançava fazer interrocedo e goda e que dizem-na
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "e já sabia as ruas, e não precisava mais"
# ...Geração finalizada:
#   que se decer... já elas estavas clims; nenhunna da verdade adiojariam das enos com fora, que hei de pudovas, quasei do dágalido: a palhão baixa, adrisou... — muj. —? já como : ora, como de presegou. el-pesto que acaja : elas que tomara um pal... chegavam foi, onde, recidiu-se, ai, onágamente desprevo, e filedicos, de um lungar o atrás que entravam estudares-lhese suas criafas, e viem a rompeda: o
# 891/891 [==============================] - 116s 130ms/step - loss: 1.1879
#
# Gerando texto na época: 21
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "viera dizimada para casa, e cuja históri"
# ...Geração finalizada:
#  a do ofererado de uma das palavras do canto e a comadre de barbeiros; e a sua contra do compadre que estava a sua velha, e de que ele por aí a sua das suas que ele por um padre: da cabeça do leonardo entrar a sua das coisas passaram os dois de ser algum disso, e passavam os dois de fazer a comadre, que estava a sua das suas que se achava a sua das suas das palavras do que o que o leonardo passava
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "viera dizimada para casa, e cuja históri"
# ...Geração finalizada:
#  a que o povo de car de seu passo do seu gora do que o padrinho o oficilho tomava surdens. como de barbeiros, de ser que se acabavam que se achava sem resultado e a alguma coisa a a descrédez para empregado a alguma sana, e o nado da vez em que o seu companheiro e assim de por causa da falar a luisinha. os leitores passar a noite em gontetreça, por uma das pensamentas. a comadre, ado tempo restaram
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "viera dizimada para casa, e cuja históri"
# ...Geração finalizada:
# ...
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): " gosto a esse hábito, e em pouco tempo a"
# ...Geração finalizada:
#   que o que sabia fuê-leinhas engancia, para dar- por natenvamnham partes ômente. casar mais nota cesotava; honr. de umbas! d.smando a sápatigna por quê, não me fu— aí dar uma certa, nimerento. o tinha apesar da velha vino, e sate aãepuinham elas, rmparávia ver fez um dia de logo ez poécaca dar-se ser vindas perdo imenáalinha, dirigindo-sa. ocupava por insufimárias na iída de sra esconhece gravala,
# 891/891 [==============================] - 120s 134ms/step - loss: 1.1444
#
# Gerando texto na época: 33
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "ispersas dos autos que o menino despedaç"
# ...Geração finalizada:
#  a na cabeça do mais dia de contentido e a comadre de desatirou-se em contentimento. estavam com a comadre de casa de seu pai contar a comadre de desta deles e passou a comadre de que ele a comadre de cabeçado a comadre de cara de casa de servir do mais dia de casa de contentamente a cabeça de todas as reputações do capitão de casa de desatiroção de casa de cara de seu pai de desatiroço a comadre d
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "ispersas dos autos que o menino despedaç"
# ...Geração finalizada:
#  a ao olhar do dia de repente de fazer de mais que desse arrem em contentimento de casa de cara de seus primeiros sigsedia a minha pequena com de tudo que disse a vizinhança mestre de pasto e primeiro e muito algumas coisas com o tempo no mais depois de casa de d. maria. o capitão do tempo de não se empre entrara a cabeça... esta martase procissão de cabelos e morteiro de casa, e cabeçada e estreit
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "ispersas dos autos que o menino despedaç"
# ...Geração finalizada:
#  a que ela sofr. a desconveciado, e posto a disdiliante. com o menindo dizer seus miliores, e não tem dizer, vendo escravente em família é que ela que o peva zeu o responsos, de serviços de repeterida de que em algamos barbes, arrjuzar-lhe sobre a quem passado o leonardo então fremes, como quem parecia cabeça. uma coisa. luisinha e a pouco dia. diremendo. disso... patacala: se então que se apresent
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "ispersas dos autos que o menino despedaç"
# ...Geração finalizada:
#  amava. e pabam cá clésurio... — vedomam foi cigar-sade plaia de lendar de acrediça... dos frascos de lençaiem. a conttrumaquela dainte um mais voltudo metisulso mesmos instaviam sonda, por simíplo, uma séria com outra, apauida. oão sifses amor crias,dou-um livro, e seguinda e que eu presavela o estado uma fagora fica a corrusempado de tão desanado, um genteo dando branútão, e da abanliarigabé diga
# 891/891 [==============================] - 122s 137ms/step - loss: 1.1445
#
# Gerando texto na época: 34
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "tra coisa assim, e que por fim de contas"
# ...Geração finalizada:
#   do que se passava de pontumento de todas as mais as cantas da sala, e em casa de tudo a casa de um passos de seu pai. o leonardo para a cada mentinha de toda a casa de passadas para a comadre para a cada de diante de serviço a primeira pequena de serviço e as mãos de uma conversa de passas de casa de todas as mais as pensas de casa de uma dela, e a comadre de toda a seu nome. e sabia desaronchada
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "tra coisa assim, e que por fim de contas"
# ...Geração finalizada:
#   de minha era a eleva e para as duas procurações, e serviaria para ser pouco, e tanto meio de tudo, e se entretanto a vida do pequeno, a tempo também em conta de contentinho, e disse o corpo do primeiro como tinha também sabia a cabeça alguma coisa o vidigal da conta das martas de braço tão acorderadas, e sofreu a comadre com o menino de minha não estava em casa, e eu acabaram os solhados do leona
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "tra coisa assim, e que por fim de contas"
# ...Geração finalizada:
#   concareiros, quem decerdo no alhigilio de nês seu partela, nem possi!... o major os chavo chiquinha, a pastão la gassaras, e dizeros mais achar a roda e chegar o aquela!... também em defeita pela cabel na comadre diaco, também o perdora as passa de d. maria o trajava o mestre de largora às sirgar-se a reponada. o sai, de quem tem estava lugado de sair tentalmento, e pe; escoças asolhavam. não hiv
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "tra coisa assim, e que por fim de contas"
# ...Geração finalizada:
#  ira, e ouviu o leonardo massià!.. começara na imão. era lá apressado entender o ter diar-lhe toanes as mãos. o olhasse, mmãola, mera já prazo de luisinha, e que agora se é o que ispontrme meíbis ! já setira mejolo das canccessas conças é maviabra: ocabião do leonardo trazia -féujo ocubiu um dia alfirnva-se da obre da sala e gapar, reulizada no rincpa, e chamaram sentam. adente para onjente matacat
# 891/891 [==============================] - 120s 135ms/step - loss: 1.1403
#
# Gerando texto na época: 35
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "uem não as tem; o rapaz desta vez tem to"
# ...Geração finalizada:
#  mar a comadre de seus perturos do tempora do que tava pela cabeça do compais de casacado, e a comadre por casa de seu pensava a comadre perteitou-se e de seus perdãos de sua casa de seu pela casa de uma deles por onde se achava a comadre pertou a parte de seus palhos do temporo, e por isso estava a comadre travavam de seus palhos do leonardo por isso porém uma coisa dizer a comadre por casa de seu
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "uem não as tem; o rapaz desta vez tem to"
# ...Geração finalizada:
#  do em pouco compadre, achou o ter dizer; se por ele estava a comadre todo o compadre em que tinham de sua casa de rapariga... deiste não casa de lhe dessa conhecida da maria, e pelisso atentegreles de meste antigo... — queria mais ou menos de sua velha de seu serviço em custo. e sua sacia de seus palhos da gente dar em casa o compadre de outro. — qual!... — qual!... a vizinhança de todas as menas
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "uem não as tem; o rapaz desta vez tem to"
# ...Geração finalizada:
#  do em si; ah! sento à ordinha, que mais dia pois. os felizos do quartos homem ter tazqumenta esextço da avaflor que erava para a só fazer de agora possível, tantasse certustas; crios de carcure da migro, e o adaindo, que não foi de respeito e sortes de descançado pois de repertadeiras, tem paquilo, auddavna. as velhas que não curios de mes anos de irmãos atinar-lhe de comadre. uma dem vago ter com
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "uem não as tem; o rapaz desta vez tem to"
# ...Geração finalizada:
#  do sofertel, seus palconciliória; mapatecer renuxaram desventou-os pessoas de um infunocsago da mariação de foi-na saira. desta brcor pela saticia, travara o mondeco por muita gargalhada velha pretertamente, e eu mil d pucado pelas sistrades pareces que sabeiro seu liflicartendo: leuxormandos imperab; um corr, da rótula coisa a mais que saritadois sra. — não fi. incorreu depois de certos pervivos
# 891/891 [==============================] - 121s 136ms/step - loss: 1.1375
#
# Gerando texto na época: 36
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "guinchos e esperneios. à maria avermelha"
# ...Geração finalizada:
#  ra de sua cidade de casacedo ao amor apenas a comadre de tomado a comadre de seus pareces; e se estava ele se passava de ser altar em casa de seu pai, de sua cadeirinha. o capitão de desafiar-se por mais a respeito de alguma de sua mantilha a comadre de sua cabeça, e tanto que se passava a cabeça, e desatava a comadre de seu pouco desatara a comadre, e a comadre de casachado a comadre para a comad
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "guinchos e esperneios. à maria avermelha"
# ...Geração finalizada:
#  ram-se em que tanto mais a vez o major manticibimônia ao pés e a comadre contava a respeito de casacho. desta vez que a comadre ao primeiro chiquirta e companheira. tendo-se de fazer para a causa. disto se primeiro ao compadre explicava com o leonardo era muito tempo tomado a comadre de exercido de mandas de sua retanhada e mestre-de-reza, que ele estava estar por ocasigio de tudo a cabeça desta c
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "guinchos e esperneios. à maria avermelha"
# ...Geração finalizada:
#  s!,àààuas... a leutra; antendeu por mais; e temiam largo causa man-lina que saíam por sair? o leonardo lassendas, e penber o negócio, aturaza e o esperando. ela se homem, e algum diziam se chegará ela acompanhia da risa aveàmaga à cadeirão; começou uma apesar-se sobre elas? — tendo-se distraíça que o perder; a depoi! tevesse. todou apressado na ucharia que o negócio de atrivê-la capaz, ouviu muito
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "guinchos e esperneios. à maria avermelha"
# ...Geração finalizada:
#  m os qui. os doitos ; sidailhas e nas mandausa; efereu-lhe pois este diabo; morificava de és... vazpemo, respeità qunsão, rimosa, possustava por meda antesado como foiros concl!idtiram quase a sonida, desta é, achumpre, como faz rqui enfaminhor, em que já se dizia. çaósso um peç; desedidado razões de malginha. as vezes, e há de dar onde era chegou com o ilhobem último; e o mario, taldiria por isso
# 891/891 [==============================] - 119s 134ms/step - loss: 1.1354
#
# Gerando texto na época: 37
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "uca coisa de notável. fora leonardo algi"
# ...Geração finalizada:
#  m destas acompanhados de seus primeiros depois da comadre por algum destino do capitão de casa de contra eles procurar a desarindo-se a comadre de seu pai, de seu serviço de seus primeiros perdendo a comadre, e a comadre de seus primeiros de seu pai que ele por isse. e desatou a comadre percebendo-se a comadre de servir de seus primeiros depois da cabeça de seus primeiros de seu procuro de seus pr
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "uca coisa de notável. fora leonardo algi"
# ...Geração finalizada:
#  ns o que era a comadre de que elas vezes maligo ela e que o negócio com a comadre a vidrilila de repartar de trabendo o amor do leonardo, que entrava de menos chiquinhas como quem; sei ao seu irmão de virtude, e desabria o beres que elas coisas como o velho acompanhado naquele tempo; está deles de vidinha, para o menino em semelhante apesar o menino a algum sentado que ele desprandeu o leonardo co
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "uca coisa de notável. fora leonardo algi"
# ...Geração finalizada:
#  ufente parjula mais gozenfora de grande que casava estas projeíções decimitares de ver de fédo era juíto de notínio, o cabocruçado de mimprfetar-se de um dos leitoremos à cura. — vamos está tudo não prevenem voltado. na réçiga vaída não se ocudiu o leonardo para foi acordiação der-se que ele começou a primeira pequena reito! — é já lhe a primeiro perfectar com a prima discurs da ir às cudas, da su
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "uca coisa de notável. fora leonardo algi"
# ...Geração finalizada:
#  am posso; porém não tadia a supago o vestidiezanta para força; segurando vidinha te para diante em lisxa o cuidado por aquele rancte, estava à paredera dia; enumeubrecuzavam os tru-elatos; pela vozer, dos que coderas de escado. desterio; é seis ; ora pricado! contra vez ao falar; é uma fatura naquele tempo hir qufecdos verestem sempre um pelo nisso, disse remoçados, a calcado vieinos na competbeir
# 891/891 [==============================] - 120s 135ms/step - loss: 1.1327
#
# Gerando texto na época: 38
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "agra, severa e sarcástica do nosso céleb"
# ...Geração finalizada:
#  o em companheia de desafiar-lhe a porta. — e o major a comadre de desafia de contar e a princípio por algum canto de seu pernar de seu pernado de seu pernar de seu pai desanio de apenas a princípio de apenas o major a comadre de contar o compadre a comadre se passava a princípio, e perdeu-lhe um pouco por algum dia em conversa de seu pai, disse-lhe para a comadre, e estava a comadre de desapidade
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "agra, severa e sarcástica do nosso céleb"
# ...Geração finalizada:
#  o das persos da conhecida de resultado na casa de contar mais sobre o leonardo para entre os travesse muitos mais não se disse: — e o primeiro uma cara de pedra. o leonardo acompanhada de casa de desafia de chegar ao porte. pelo conta risada: a comadre começou a paredidade de casa de seu pai naquele tempo por um pouco demos os leitores que se encaia-se o compadre a respondir sem dúi— para em para
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "agra, severa e sarcástica do nosso céleb"
# ...Geração finalizada:
#  o entretanto com o major o vidinálinho, e solteiro sabia, pensazada. — é quer velha fei-se pinha malignar pelo campo de novo de seu ragar de enfiança ou mal por onde vivia estadeiro em despidadeiro da grande emorrada e daquile interrompeciava-se assentes convidamentes pelo gosto da concilça que tivera menino. josé manuel, se o compadre se os dias deles: estavam se em todas as vozeras, e sorriu-se
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "agra, severa e sarcástica do nosso céleb"
# ...Geração finalizada:
#  ar de maria-regai dobringeirada. elas hora. — é um leonardo, a que estivessem coração etase queo mas em que era. — poico, não ; e pôs-se a ólido no lato a renltante é saiu de que se fosse, e também nascei melhá nino, e bom volémpo maior ninferra de desembara daà susoeme; a futiga, mas então, apedram luisinha, não . podiava uma que não o mestre-de-cerimônia, minha há muito temceiro. — mas quem tinh
# 891/891 [==============================] - 120s 134ms/step - loss: 1.1278
#
# Gerando texto na época: 39
# ...Diversidade: 0.2
# ...Gerando com a semente (sentença): "s contas ajustadas completamente entre o"
# ...Geração finalizada:
#   leonardo por que a comadre com ele, porque e a comadre, porém não porque para tempo de cargado. — pois a comadre, e para cá muito tempo, e a sua cada mantilha e o que ele por mais de todas as mais as de papres de ser de ser a descrerosá-lo, a comadre, que o leonardo para da coisa e a sua comadre, e para cá estido por que ele por cara de pobre algum dia de conversa e a comadre, com o leonardo por
# ...Diversidade: 0.5
# ...Gerando com a semente (sentença): "s contas ajustadas completamente entre o"
# ...Geração finalizada:
#   leonardo era um pouco desatirou-se em um serviço de grande por isso não acrescentou talvez o leonardo, nergunemos a procisada, e tinha que as coisas que eram com isso, como a própiia de que ele porém não há uma das suas novas eram o resultado de ser por cabelo de com de muito bem. — não se pareceu de vinha a conhecimenta de todas as mulheres de amor em coisa ou não de desatárem a porta da cidade
# ...Diversidade: 1.0
# ...Gerando com a semente (sentença): "s contas ajustadas completamente entre o"
# ...Geração finalizada:
#  nde, com e um dia que ele antigo, ou outro; e encantou para casa de um ser. a casa de verdadeiro, serviça rouniu, lalçass. e lhe casa de seu toda em que se acabara de levar a trapenda de uma mulher de píprósurs, perquando o : o padre isto queru, deixar na cabeça, e foi-se já quero soltarám ao pesada de cargos homem deixar lá sofilhadoro; e sobre o pisade-cores verdadeiros do breve no meler primeir
# ...Diversidade: 1.2
# ...Gerando com a semente (sentença): "s contas ajustadas completamente entre o"
# ...Geração finalizada:
#   pequeno, o havia ólivor a elasco-pulher de lê-las, cirmuror. leonardo, a futura nos imemam-q! — féiol, e camos a outra, pena l ólizado conhecido por cá não foi um prosruuce. negras cimedadas; era esacartuxada o pobre vindo e companhee diabo. ninguído, se levou que a escu—va de ser gracadeiro. é dia pares que ia este não gravem, depois cor. a levona inspersormente de sempre o ninho; enganava com o
